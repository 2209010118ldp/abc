# %% [markdown]
# #### 生成虚假评论

# %%
import random


WINDOW_SIZE = 10
PUNCTUATION_MARK = ['x']  # 标点
PUNCTUATION = ['。', '！', '？', '，', '～']
NOUN_MARK = ['n', 'ng', 'nr', 'nrfg', 'nrt', 'ns', 'nt', 'nz']  # 名词
VERB_MARK = ['v', 'vd', 'vg', 'vi', 'vn', 'vq']  # 动词
ADJECTIVE_MARK = ['a', 'ad', 'an', 'ag']  # 形容词
ADVERB_MARK = ['d', 'df', 'dg']  # 副词
ENG_MARK = ['eng']

EMOJI = ['😀', '😁', '😂', '😃', '😄', '😆','😉', '😊',
         '😋', '😎', '😍', '😘', '😗', '😙', '😚', '😇',
         '😏', '😝']

YANWENZI = ['ヽ(✿ﾟ▽ﾟ)ノ', 'φ(≧ω≦*)♪', '╰(*°▽°*)╯', 'o(￣▽￣)ｄ', 'o( =•ω•= )m']

ILLEGAL_WORD = ['考拉', '网易']  # '不过', '因为', '而且', '但是', '但', '所以', '因此', '如果',


RESERVED_MARK = NOUN_MARK + VERB_MARK + ADJECTIVE_MARK + ADVERB_MARK + ENG_MARK # 用于发现新词
ASPECT_MARK = NOUN_MARK + VERB_MARK


def text2seg_pos(seg_pos_text, pattern='[。！？]'):
    """
    经过分词的文档，原始一条用户评论通过指定的标点符号分成多个句子
    """
    seg_list = []  # 保存全部按标点切分的seg
    pos_list = []  # 保存全部按标点切分的pos
    seg_review_list = []  # 用户完整的一条评论
    for line in seg_pos_text:
        line = line.strip()
        line = line.split(' ')
        seg_sub_list = []
        pos_sub_list = []
        cur_review = []
        for term in line:
            word, flag = term.split('/')
            cur_review.append(word)
            if word in pattern:
                seg_sub_list.append(word)
                pos_sub_list.append(flag)
                seg_list.append(list(seg_sub_list))
                pos_list.append(list(pos_sub_list))
                seg_sub_list = []
                pos_sub_list = []
            else:
                seg_sub_list.append(word)
                pos_sub_list.append(flag)
        seg_review_list.append(list(cur_review))
    return seg_list, pos_list, seg_review_list


def get_candidate_aspect(seg_list, pos_list, adj_word, stop_word, word_idf):
    """
    输入的数据为用逗号隔开的短句，
    利用开窗口的方式，根据情感词典抽名词得到候选的aspect
    """
    print("利用情感词典抽取候选aspect...")
    aspect_dict = {}
    print(adj_word[:100])
    for i, sentence in enumerate(seg_list):
        for j, word in enumerate(sentence):
            if word in adj_word:
                #print(1)
                if pos_list[i][j] in ADJECTIVE_MARK:  # 当前的词属于情感词且词性为形容词
                    #print(2)
                    startpoint = j - WINDOW_SIZE
                    startpoint = startpoint if startpoint >= 0 else 0
                    for k in range(startpoint, j):
                        if pos_list[i][k] in ASPECT_MARK:
                            #print(3)
                            if seg_list[i][k] in aspect_dict:
                                aspect_dict[seg_list[i][k]] += 1
                            else:
                                aspect_dict[seg_list[i][k]] = 1

    temp = aspect_dict.items()
    #print(temp)
    temp = list(filter(lambda x: len(x[0]) > 1, temp))  # 经过词组发现之后，删去一个字的词
    temp = [item[0] for item in temp if item[0] not in stop_word]  # 删去停用词
    #print(temp)
    temp = [item for item in temp if word_idf[item] != 0]  # 删去IDF值为0的词
    #print(2,temp)
    aspect_list = temp
    print("---aspect抽取完成，共抽取到%s个候选aspect---" % (len(aspect_list)))
    return aspect_list


class NSDict:
    """
    用来构建候选集（aspect，opinion，pattern）
    """
    def __init__(self, seg_list, pos_list, raw_aspect_list):
        self.seg_list = seg_list
        self.pos_list = pos_list
        self.raw_aspect_list = raw_aspect_list
        self.ns_dict = {}
        self.aspect_do_not_use = []
        self.opinion_do_not_use = ["最", "不", "很"]
        self.pattern_do_not_use = ["的-", "和-", "和+", "而+", "而-", "又+", "又-", "而且+", "而且-"]

    def _seg2nsd(self, aspect_for_filter):
        for x, clue in enumerate(self.seg_list):
            N_list = []
            S_list = []
            word_list = clue
            for y, word in enumerate(clue):
                if word in aspect_for_filter:
                    N_list.append(y)
                elif self.pos_list[x][y] in ADJECTIVE_MARK:
                    S_list.append(y)
            if N_list and S_list:
                self._make_nsdict(word_list, N_list, S_list)

    def _make_nsdict(self, word_list, N_list, S_list):
        for n in N_list:
            for s in S_list:
                if (1 < n - s < WINDOW_SIZE + 1) or (1 < s - n < WINDOW_SIZE + 1):  # 窗口大小是5
                    if word_list[n] not in self.ns_dict:
                        self.ns_dict[word_list[n]] = {}
                    if word_list[s] not in self.ns_dict[word_list[n]]:
                        self.ns_dict[word_list[n]][word_list[s]] = {}
                    if n > s:
                        patt = ' '.join(word_list[s + 1: n]) + '+'
                    else:
                        patt = ' '.join(word_list[n + 1: s]) + '-'
                    if patt not in self.ns_dict[word_list[n]][word_list[s]]:
                        self.ns_dict[word_list[n]][word_list[s]][patt] = 0.
                    self.ns_dict[word_list[n]][word_list[s]][patt] += 1.

    def _noise_del(self):
        for aspect in self.aspect_do_not_use:
            self._noise(aspect, self.ns_dict)
        for n in self.ns_dict:
            for opinion in self.opinion_do_not_use:
                self._noise(opinion, self.ns_dict[n])
            for s in self.ns_dict[n]:
                for pattern in self.pattern_do_not_use:
                    self._noise(pattern,self.ns_dict[n][s])

    def _noise(self, str, dict):
        if str in dict:
            del dict[str]

    def build_nsdict(self):
        print("stage 1：抽取pair和pattern...")
        self._seg2nsd(self.raw_aspect_list)
        self._noise_del()
        print("\tDone")
        return self.ns_dict


class PairPattSort:
    '''
    Pair-Patt-Count structure
    '''
    def __init__(self, ns_dict):
        self._get_map(ns_dict)

    def _get_map(self, ns_dict):
        '''
        get map: [pair-patt], [patt-pair], [pair](score), [patt](score)

        :param ns_dict: Entity.str { Emotion.str { Pattern.str { Count.int (It's a three-level hash structure)
        :return:
        '''
        pair_list = []
        patt_dict = {}
        patt_pair_map = {}
        pair_patt_map = {}

        aspects = list(ns_dict.keys())
        aspects.sort()

        for n in aspects:
            for s in ns_dict[n]:
                n_s = "{}\t{}".format(n, s)   #这里存的pair是字符串，中间用\t隔开
                pair_list.append(n_s)
                pair_patt_map[n_s] = {}
                for patt in ns_dict[n][s]:
                    if patt not in patt_dict:
                        patt_dict[patt] = 1.0
                    pair_patt_map[n_s][patt] = ns_dict[n][s][patt]
                    if patt in patt_pair_map:
                        patt_pair_map[patt][n_s] = ns_dict[n][s][patt]
                    else:
                        patt_pair_map[patt] = {}
                        patt_pair_map[patt][n_s] = ns_dict[n][s][patt]
        self.patt_pair_map = patt_pair_map
        self.pair_patt_map = pair_patt_map
        self.pair_len = len(pair_list)
        self.patt_len = len(patt_dict)
        self.pair_score = dict([(word, 1.) for i, word in enumerate(pair_list)])
        self.patt_score = patt_dict

    """"正则化，和为score_len"""
    def _norm(self, score_dict, score_len):
        sum_score = 0.
        for s in score_dict:
            sum_score += score_dict[s]
        for s in score_dict:
            score_dict[s] = score_dict[s] / sum_score * score_len
        return score_dict

    def _patt_pair(self):
        for pair in self.pair_patt_map:  # <- 循环遍历每个pair
            value = 0.
            for patt in self.pair_patt_map[pair]:  # <- 每个pair中的pattern出现的个数 * 这个pattern的score，然后求和得到这个pair的分数
                value += self.pair_patt_map[pair][patt] * self.patt_score[patt]
            self.pair_score[pair] = value

    def _pair_patt(self):
        for patt in self.patt_pair_map:  # <- 遍历每个pattern
            value = 0.
            for pair in self.patt_pair_map[patt]:  # <- 每个被pattern修饰的pair出现的个数 * 这个pair的score，然后求和得到这个pattern1的
                value += self.patt_pair_map[patt][pair] * self.pair_score[pair]
            self.patt_score[patt] = value
    def _patt_correct(self):
        self.patt_score['的-'] = 0.0

    def _iterative(self):
        '''
        A complete iteration
        [pair] = [patt-pair] * [patt]
        [patt] = [pair-patt] * [pair]
        :return:
        '''
        self._patt_pair()
        self.pair_score = self._norm(self.pair_score, self.pair_len)
        self._pair_patt()
        self.patt_score = self._norm(self.patt_score, self.patt_len)

    def sort_pair(self):
        print("stage 2：组合排序...")
        for i in range(100):
            self._iterative()
        pair_score = sorted(self.pair_score.items(), key=lambda d: d[1], reverse=True)
        print('\tDone')
        print("---pair抽取完成---")
        return pair_score


def get_aspect_express(seg_review_list, pair_useful):
    """
    抽取原始评论中的aspect作为输入，完整的评论作为输出
    """

    def check_sentence(sentence):
        """
        判断短句是否合法
        """
        _s = ''.join(sentence)
        legal = True
        if len(_s) > 30:
            legal = False
        return legal

    raw_aspect_express = {k: [] for k in pair_useful}  # 用户关于某个观点的一段原始表达
    raw_aspect_express_count = {k: 0 for k in pair_useful}  # 记录某个观点表达出现的次数
    for review in seg_review_list:  # 每个sentence就是一句完整的review

        source = []  # 训练的src
        if review[-1] not in PUNCTUATION:
            review.append('。')
        target = review  # 训练的tgt

        # 对于单个review进行切分
        cur_review = []
        pre_end = 0
        for i, _ in enumerate(review):
            if review[i] in ['。', '！', '？', '，', '～']:
                cur_review.append(review[pre_end:i + 1])
                pre_end = i + 1
            elif i == len(review) - 1:
                cur_review.append(review[pre_end:])

        for sentence in cur_review:  # sentence 是两个标点之间的短句
            if sentence[-1] not in PUNCTUATION:
                sentence.append('。')
            find_opinion_flag = False
            for idx, word in enumerate(sentence):
                if find_opinion_flag:  # 如果在当前的短句中已经找到了一组观点表达就结束对这个短句的搜索
                    break
                if word in pair_useful:  # 当前的word属于aspect
                    # 向前开窗口
                    startpoint = idx - WINDOW_SIZE if idx - WINDOW_SIZE > 0 else 0
                    for i in range(startpoint, idx):  # 寻找opinion word
                        cur_word = sentence[i]
                        if cur_word in pair_useful[word] and sentence[i + 1] == "的":  # eg. 超赞的一款面膜
                            if check_sentence(sentence):
                                raw_aspect_express[word].append(sentence)
                                raw_aspect_express_count[word] += 1
                                find_opinion_flag = True  # 只要找到一个opinion word就算命中一个短句了

                    # 向后开窗口
                    endpoint = idx + WINDOW_SIZE if idx + WINDOW_SIZE < len(sentence) else len(sentence)
                    for i in range(idx + 1, endpoint):
                        cur_word = sentence[i]
                        if cur_word in pair_useful[word]:
                            if check_sentence(sentence):
                                raw_aspect_express[word].append(sentence)
                                raw_aspect_express_count[word] += 1
                                find_opinion_flag = True  # 只要找到一个opinion word就算命中一个短句了

    # 筛选得到保留的aspect
    aspect_express = {}
    for aspect in raw_aspect_express:
        if raw_aspect_express_count[aspect] < 5:
            continue
        aspect_express[aspect] = raw_aspect_express[aspect]

    return aspect_express


def merge_aspect_express(aspect_express, pair_useful):
    """
    对相似的观点表达进行合并, 同时输出最终的aspect_opinion_pair
    """
    aspects = list(aspect_express.keys())
    length = len(aspects)
    aspects.sort()  # 排成字典序
    merged_aspects = [[aspects[0]]]
    merged_express = {}
    opinion_set = []

    def check_is_same(word1, word2):
        """
        判断两个词当中是否存在相同的字
        """
        for i in word1:
            if i in word2:
                return True
        return False

    for i in range(1, length):
        if check_is_same(merged_aspects[-1][-1], aspects[i]):
            merged_aspects[-1].append(aspects[i])
        else:
            merged_aspects.append([aspects[i]])

    for a_list in merged_aspects:

        # 收集全部的形容词
        for i in a_list:
            opinion_set += pair_useful[i]

        _l = ','.join(a_list)
        merged_express[_l] = []
        for i in a_list:
            merged_express[_l] += aspect_express[i]

    opinion_set = set(opinion_set)

    return merged_express, opinion_set


def build_dataset_express(seg_review_list, pair_useful):
    """
    抽取原始评论中的aspect作为输入，完整的评论作为输出
    """
    train_data = []  # 记录训练数据
    for review in seg_review_list:  # 每个sentence就是一句完整的review

        source = []  # 训练的src
        if review[-1] not in PUNCTUATION:
            review.append('。')
        target = review  # 训练的tgt

        # 对于单个review进行切分
        cur_review = []
        pre_end = 0
        for i, _ in enumerate(review):
            if review[i] in ['。', '！', '？', '，', '～']:
                cur_review.append(review[pre_end:i + 1])
                pre_end = i + 1
            elif i == len(review) - 1:
                cur_review.append(review[pre_end:])

        for sentence in cur_review:  # sentence 是两个标点之间的短
            if sentence[-1] not in PUNCTUATION:
                sentence.append('。')
            find_opinion_flag = False
            for idx, word in enumerate(sentence):
                if find_opinion_flag:  # 如果在当前的短句中已经找到了一组观点表达就结束对这个短句的搜索
                    break
                if word in pair_useful:  # 当前的word属于aspect
                    source.append(word)
                    find_opinion_flag = True  # 只要找到一个opinion word就算命中一个短句了

        train_data.append((list(source), target))

    max_source_length = 0
    # 筛选训练数据
    def check_review(item):
        """
        判断当前review是否合法
        """
        source = item[0]
        tgt = item[1]
        legal = True
        _s = ''.join(tgt)
        if len(source) == 0 or len(source) > 5:  # 不含有观点表达或者观点词太多
            legal = False
        unique_source = set(source)
        if len(unique_source) != len(source):
            legal = False
        if len(_s) > 60:
            legal = False
        return legal

    legal_train_data= []
    for item in train_data:
        if check_review(item):
            max_source_length = max(max_source_length, len(item[0]))
            legal_train_data.append(item)

    print('max source length:%s' % max_source_length)
    return legal_train_data


def generate_reviews(aspect_express, num=1000):
    """
    根据候选集合生成假评论
    """
    all_aspect = list(aspect_express.keys())
    print('Aspect:{}'.format(all_aspect))
    print()

    # 根据不同aspect出现的概率分配不同权重
    aspect_length_dict = {}
    for a in aspect_express:
        aspect_length_dict[a] = len(aspect_express[a])
    weight_aspect_list = []
    for aspect in aspect_length_dict:
        weight_aspect_list += [aspect] * aspect_length_dict[aspect]

    res = []
    for _ in range(num):
        num_aspect = random.choice([1, 2, 3, 4, 5, 6])
        review = []
        used_aspect = []
        for _ in range(num_aspect):
            a = random.choice(weight_aspect_list)
            while a in used_aspect:
                a = random.choice(weight_aspect_list)
            used_aspect.append(a)
            a_s = random.choice(aspect_express[a])
            a_s = a_s[:-1] + ['#']  # 丢掉标点，换位#作为切分点
            review += a_s
        res.append(review)

    return res


def fake_review_filter(reviews, opinion_set):
    """
    筛去评论中不像人写的句子：如果同一个形容词重复出现两次就判定为假评论，同时筛去长度超过60的评论
    """
    results = []
    for review in reviews:
        opinion_used = {k: 0 for k in opinion_set}
        flag = True
        for word in review:
            if word in ILLEGAL_WORD:
                flag = False
            if word in opinion_used:
                opinion_used[word] += 1
                if opinion_used[word] >= 2:
                    flag = False
                    # print('Fake:{}'.format(''.join(review)))
                    break
        if flag:
            _s = ''.join(review)
            _s = _s.split('#')  # 最后一个是空字符
            review = ''
            pu = ['，'] * 100 + ['～'] * 20 + ['！'] * 20 + EMOJI + YANWENZI
            random.shuffle(pu)
            for a_s in _s:
                if a_s:
                    review += a_s + random.choice(pu)
            if not review:
                print('error:')
                print(review)
            review = review[:-1] + '。'
            results.append(review)
            print('\t' + review)

    return results

# %%
# 利用抽取的方法从原始评论中抽取含有观点表达的短句，并随机组合一些含有观点表达的短句组成一句仿真评论。
with open('../data(temp)/review_cleaned.txt', 'r',encoding='utf-8') as f:
    str_text = f.read()
with open('../data(temp)/review_seg_post.txt', 'r',encoding='utf-8') as f:
    seg_pos_text = f.readlines()

# 加载IDF表
word_idf = {}
with open('../data(temp)/review_idf.txt', 'r',encoding='utf-8') as f:
    for line in f.readlines():
        word, idf = line.strip().split(' ')
        word_idf[word] = float(idf)

# 加载停用词
stop_word = []
with open('../data/stopword.txt', 'r',encoding='utf-8') as f:
    for line in f.readlines():
        stop_word.append(line.strip())

# 加载正向情感词典
pos_adj_word = []
with open('../data/HowNetPOSWord.txt', 'r',encoding='utf-8') as f:
    for line in f.readlines():
        pos_adj_word.append(line.strip())

seg_list, pos_list, seg_review_list = text2seg_pos(seg_pos_text, pattern='[。！？，～]')
raw_aspect_list = get_candidate_aspect(seg_list, pos_list, pos_adj_word, stop_word, word_idf)
# 构建候选集合
N = NSDict(seg_list, pos_list, raw_aspect_list)
ns_dict = N.build_nsdict()
# 候选集合排序
P = PairPattSort(ns_dict)
pair_score = P.sort_pair()
# 得到正确的观点表达候选
pair_useful = {}
baseline = 0.1 * len(pair_score)
for i, item in enumerate(pair_score):
    if i <= baseline:
        aspect, opinion = item[0].split('\t')
        if aspect in pair_useful:
            pair_useful[aspect].append(opinion)
        else:
            pair_useful[aspect] = [opinion]

# 从原始评论中抽取观点表达
aspect_express = get_aspect_express(seg_review_list, pair_useful)

# 字符匹配合并aspect
merged_aspect_express, opinion_set = merge_aspect_express(aspect_express, pair_useful)

# 生成假评论
generated_raw_reviews = generate_reviews(merged_aspect_express)

results = fake_review_filter(generated_raw_reviews, opinion_set)

with open('../results/generated_reviews.txt', 'w',encoding='utf-8') as f:
    for c in results:
        f.write(c + '\n')
# Out:
# 利用情感词典抽取候选aspect...
# ['侻', '俶傥', '僄', '劼', '嫕', '惇', '惓惓', '會', '牣', '皞', '挨边', '哀婉', '哀艳', '蔼', '蔼蔼', '蔼然', '蔼然可亲', '蔼如', '艾', '碍事', '安', '安安静静', '安安稳稳', '安定', '安顿', '安分', '安好', '安静', '安康', '安澜', '安乐', '安宁', '安全', '安然', '安然无事', '安然无恙', '安如磐石', '安如泰山', '安生', '安适', '安泰', '安恬', '安稳', '安详', '安逸', '安谧', '按期', '按时', '昂昂', '昂藏', '昂然', '傲然', '奥', '奥博', '奥妙', '巴结', '拔尖', '拔尖儿', '拔俗', '把牢', '把稳', '把细', '白', '白纸黑字', '百不一失', '百读不厌', '百废俱兴', '百里挑一', '百炼成钢', '百听不厌', '百无一失', '百依百顺', '百折不回', '百折不挠', '百折不挠地', '板板正正', '板实', '板正', '半公开', '半透明', '膀大腰圆', '膀阔腰圆', '棒', '磅礴', '苞', '睆', '保存良好', '保皇', '保险', '保准', '饱学', '宝', '宝贵', '悲壮', '卑', '倍儿棒', '备细', '奔放', '本质', '笨鸟先飞']
# ---aspect抽取完成，共抽取到393个候选aspect---
# stage 1：抽取pair和pattern...
# 	Done
# stage 2：组合排序...
# 	Done
# ---pair抽取完成---
# Aspect:['东西', '产品,产品质量', '价格', '体验,体验感', '力度', '包装', '发现,发质', '味道', '商品', '头发,头皮', '好用', '宝贝', '客服', '心情', '性价比', '感觉', '成分', '护发素', '控油', '效果', '时间', '服务态度', '气味', '油头', '泡沫', '洗出来,洗发水,洗完,洗感,洗起来', '清洁力', '留香', '能力', '脱发', '质量', '追评', '颜值', '香味']
#
# 	有去屑效果不错。
# 	效果出乎意料的好。
# 	这款洗发水去油力还是很不错的。
# 	香味也很好味。
# 	现在头发清爽蓬松了😇洗完头发很香。
# 	洗发水洗了很清爽，用了效果不错，包装完好物流快！泡沫丰富。
# 	去屑效果好，不仅味道香。
# 	包装很仔细、严实。
# 	头发洗完第一天一点也不蓬松😃商品气味很香😊感觉还不错～而且这款洗发水成分很温和，包装的很严实😆控油的也挺好。
# 	洗发水泡沫丰富细腻而且头发能维持好几天不油，商品气味好闻香，它的成分温和。
# 	头发感觉洗的老干净了～商品气味很好～包装完整。
# 	头发洗了很柔顺。
# 	洗完清爽蓬松φ(≧ω≦*)♪洗护效果明显。
# 	当天追评特别好。
# 	洗完头发柔顺丝滑😁很清爽的感觉，商品气味好～头发洗完都蓬松了。
# 	味道也很香😃就很棒头皮又干净又清爽，包装完好，泡沫细腻丰富～50天后追评洗头水很好！洗完很蓬松。
# 	控油去屑效果特别好，香味比较持久。
# 	控油效果不错😀质量非常好～味道也很香，头发也变得柔顺了许多，性价比高😏而且它的成分温和o( =•ω•= )。
# 	包装也很精致，去油去屑效果好，这款洗发水是朋友使用以后觉得很不错。
# 	效果真的不错。
# 	洗完的发质蓬松柔软，感觉挺好的，洗后头皮感觉很舒服，包装完好。
# 	味道也很清新😆洗完头皮很清爽～控油效果不错，头发柔顺亮泽，且清洁力强，我简直不敢相信在淘宝上能买到质量这样好o( =•ω•= )。
# 	味道很香，控油蓬松都很好😇他们也都说效果不错，香味持久。
# 	控油效果好，以前用过味道不错。
# 	用完头发柔顺不毛躁。
# 	头发就没有支棱起来过来现在头发都是蓬松的，而且控油效果持久，体验感特别差～去屑的柔顺的都好用。
# 	它不仅让我的头发保持清爽～84天后追评还不错。
# 	头发蓬松，9天后追评真的很不错的洗发水。
# 	使用效果很差，很控油洗完头后特别清爽舒适，泡沫绵密细腻，闻起来的味道也很好。
# 	控油洗发水用后头发非常蓬松！很温和的洗发水。
# 	没有感觉到头发蓬松！这样头发就更干净舒爽了，香味清新淡雅！泡沫丰富，22天后追评非常好用下回一定还买，这个洗发水控油效果很明显。
# 	商品气味很香，这款洗发水真的不错，洗后头皮感觉非常舒适。
# 	洗完还蓬松，而且它的成分温和。
# 	控油效果非常好，包装的很严实。
# 	使用后头发变得更加柔顺顺滑，泡沫确实挺细腻，洗完的头发很清爽，宝贝不错。
# 	包装完好。
# 	商品气味味道很香控油去屑效果很好。
# 	比之前买的洗发水好用些，气味闻着也还不错。
# 	而且洗完真的很蓬松！感觉控油也一般吧！东西不错，包装精美高端大气上档次非常好用很柔顺亮泽很满意。
# 	这个洗完头发很蓬松。
# 	对头发是油头控油效果好，洗完之后头发特别的蓬松，性价比高，效果很不错。
# 	用后头发很蓬松去油。
# 	我的头发只要在外面洗头就容易长头屑！控油效果不错，控油效果好。
# 	商品气味很香，而且洗完头发很蓬松，效果真的很好。
# 	洗完也挺柔顺的，当天追评这款洗发水特别好用。
# 	味道不错，洗后头发很柔顺😀洗完头发蓬松柔软，而且洗发水泡沫丰富，让人心情愉悦，商品气味香。
# 	这次买的洗发水还不错，头皮瞬间都感觉清爽了不少，性价比很高。
# 	去油效果也不错！香味持久，洗完后很蓬松！质量挺好的o(￣▽￣)ｄ洗完头发不怎么容易出油了，它的花香调香味让我每次洗发都感到心情愉悦。
# 	味道也不错。
# 	用完头皮确实是清爽舒服，感觉很一般，味道不错。
# 	产品很好！泡沫丰富。
# 	留香时间长，香味持久，头发都蓬松得很，控油效果好味道好闻，洗发水的香味也不错。
# 	气味很清新，洗完头发很蓬松，物美价廉使用效果很好。
# 	6天后追评现在我的头发真的很蓬松，真的感觉很不错。
# 	包装完好，效果真的很不错。
# 	让人整天心情都很愉悦，洗完清爽，去油效果很好，感觉不错的。
# 	泡沫巨丰富，效果不错，头发特别的香😆洗完头发清爽蓬松～客服态度好。
# 	感觉很不错呢第二次买了～洗起来特别舒服。
# 	洗发水香气很香～很好用物流非常快客服服务态度好。
# 	用后头发清爽不油腻，味道很好闻而且留香久。
# 	包装完好，洗完清爽。
# 	这款洗发水气味清新宜人～洗完效果蓬松。
# 	控油效果好，商品气味味道挺香的！而且洗发水这个柔顺的洗完以后。
# 	头发蓬松的发量都翻倍了。
# 	感觉还不错，包装完整！洗完之后头发很蓬松，性价比高！头皮洗完之后感觉特别清爽～而且洗发水的香味也很自然清新。
# 	用了头发很柔顺！洗头效果不错，洗完的头发轻盈又蓬松，而且性价比很高。
# 	洗发水真的很好，商品使用体验也不错，没有评价里写的味道那么香。
# 	控油效果很好，味道清新怡人～用过之后头发真的又柔顺又顺滑，洗完头皮感觉清爽的很。
# 	感觉非常好😉头发还是很柔顺！泡沫丰富，味道很香。
# 	效果都很好o(￣▽￣)。
# 	这个洗发水非常温和。
# 	泡沫细腻丰富，使用后头发很蓬松柔软😝控油效果特别好ヽ(✿ﾟ▽ﾟ)。
# 	包装也很精致，而且用完了之后头发很蓬松😋用第二次了效果不错！洗的时候泡沫丰富！洗发水很好o(￣▽￣)。
# 	这个洗发水闻起来很香，控油效果也很好！商品气味清淡的香味，宝贝很不错。
# 	头发容易塌，很香的洗发水o( =•ω•= )。
# 	冲洗后头发干净清爽～味道也很清新。
# 	清洁力很强，感觉洗完很清爽头皮也不干，性价比很高，去油效果很好😂洗发水很香。
# 	味道很香～它的泡沫丰富，洗了后头发蓬松柔顺有光泽！性价比高，用完效果特别好ヽ(✿ﾟ▽ﾟ)。
# 	泡沫丰富，洗后头发柔软顺滑😍商品气味味道不错。
# 	洗完很柔顺o(￣▽￣)ｄ头皮很清爽，泡沫非常细腻绵密😇商品气味很香，包装得很好！商品气味还不错。
# 	洗完头发很蓬松，泡沫细腻丰富，但是体验不是很好。
# 	洗了一次瞬间头皮清爽又干净，脱发严重。
# 	东西不错。
# 	味道很清新好闻。
# 	洗完了蓬松多了。
# 	洗发水买了好多次了，效果不错😂绵密细腻的泡泡在头皮上按摩很舒服，而且它的成分温和。
# 	味道很好。
# 	味道很香，这款洗发水的质量很好～让我的头发一整天都保持清爽。
# 	商品气味味道还不错，洗完头皮贼清爽。
# 	泡沫丰富，效果挺好的，头发非常柔顺。
# 	效果不错，洗完头发不油比较舒服😊商品气味挺香的。
# 	效果不错😆留香效果也很好，这样头发就更干净舒爽了。
# 	头发没有那么容易变油了😘味道也特别好😏包装精美，洗完头发很香。
# 	气味很香，我的头发比较干燥洗啦很柔顺的呢。
# 	用着感觉不错！主要性价比也高😘洗发水的控油效果真的很好。
# 	洗完可以控油时间长。
# 	洗感超级舒服。
# 	50天后追评洗头水很好，控油效果明显，洗完头发也很柔顺。
# 	我在实体店买的去屑止痒效果很好。
# 	泡沫很丰富，包装很好很严实。
# 	头发在洗完后明显清爽干净了很多～洗起来很舒服。
# 	包装完好物流快。
# 	洗完头发后清爽舒适，商品气味味道很清新，味道不错。
# 	控油效果好！商品气味很香哦，这样头发就更干净舒爽了，当天追评不错产品回购。
# 	头发真的很蓬松～感觉还不错，18天后追评洗发水很好！洗完头发很柔顺。
# 	洗完很柔顺。
# 	洗发水非常好用，洗后头发柔顺不干涩。
# 	洗完很舒服！味道也很香持久度很好，快递包装完好～头皮很舒爽。
# 	用过这款洗发水感觉非常不错～7天后追评自己用的好。
# 	商品气味香。
# 	效果非常好o(￣▽￣)。
# 	洗后头发很顺滑干爽，而且很多清洁力度很强～留香时间长，洗完也很柔顺。
# 	商品气味清新的花香，59天后追评很好洗的很干净哦亲。
# 	控油效果也不错，包装完好！头发很柔顺，洗完头发确实很蓬松，气味很舒服，让人整天心情都很愉悦。
# 	洗完头发特别蓬松，控油效果好。
# 	包装完好。
# 	用了这个洗发水效果不错，包装完整，它性价比高。
# 	还能长时间保持头皮的清爽，洗完很蓬松，味道很香。
# 	气味非常好😆味道很清新，洗完头发蓬松又柔顺。
# 	气味好味。
# 	包装完好。
# 	5天后追评用过之后感觉头发都非常蓬松，效果也不错～商品气味香味很清新舒服。
# 	洗完头皮巨干净😉体验感特别差。
# 	9天后追评这个洗发水控油效果巨好。
# 	2天后追评客服服务态度特别好。
# 	控油效果很不错。
# 	控油效果很好，包装也完整，我的头发不再那么容易出油了😘泡沫也很丰富绵密。
# 	香味也很清新😍味道很香，包装很好。
# 	东西的控油效果也很好，然后头发很蓬松，3天后追评清洁力很强。
# 	洗完很蓬松，洗后头发清爽顺滑～客服态度很好，味道很不错。
# 	泡沫很丰富，洗的头发很柔顺有一股淡淡的香味o( =•ω•= )m洗完后很清爽，洗了效果真心不错。
# 	商品气味很香的味道。
# 	头发比较容易油，现在这个洗发水用完之后三天头发还是很清爽，商品气味挺香的。
# 	商品气味香，它的成分温和。
# 	头发洗完很清爽。
# 	用完头发蓬松柔软o( =•ω•= )m商品气味很香。
# 	这个洗发水控油效果很明显，味道挺香的。
# 	气味清新，用着效果还是不错的，质量很好。
# 	很清爽的感觉。
# 	效果不错。
# 	它的控油效果也非常好，洗起来非常舒服😉头发很柔顺蓬松。
# 	产品质量好～洗完之后感觉是比其他的洗发水要蓬松一些，它的成分温和。
# 	控油效果特别好，洗发水不错，泡沫细腻丰富，11天后追评这款包装精致。
# 	包装也完好，洗完特别舒服！头皮贼清爽，对本人来说控油效果很好，味道清新。
# 	没有感觉到头发蓬松，去油能力特别强。
# 	去油效果也不错～清洁力很强。
# 	收到货包装很好～味道很不错。
# 	头发蓬松柔软，这款洗完头发真的就很柔顺😘用了一次感觉确实不错，包装精美。
# 	这个产品还不错。
# 	味道也很清新。
# 	这个洗发水对我这种油头真的友好的，香味持久。
# 	控油效果很明显，第一次够买kono味道很香、用着也好用，洗完头发也很蓬松。
# 	而且控油效果真的不错。
# 	洗起来头发很蓬松，控油效果很好。
# 	洗完柔顺多了。
# 	洗发水泡沫丰富，洗完头发非常柔顺，感觉洗完很清爽头皮也不干～控油效果好，洗后头发非常蓬松。
# 	用完之后头发特别顺比其他的护发素好用很多！它的泡沫非常丰富细腻。
# 	洗完很蓬松。
# 	使用后头发蓬松柔顺！用了效果不错。
# 	而且这个洗发水的性价比很高。
# 	质量好得没话说。
# 	冼完头皮很清爽，它的成分温和，性价比很高了。
# 	味道清新的让人心情很愉悦，更利于头发的柔软顺滑，感觉不错。
# 	洗完头发很蓬松，性价比高，包装很好，商品气味很香不刺鼻。
# 	洗后头发蓬松柔顺～167天后追评味道很好味。
# 	头发很蓬松，效果很好，商品气味味道很香！洗完头很舒服。
# 	洗完很柔顺。
# 	洗后头发柔软不打结，味道很香很好闻～泡沫丰富细腻！东西很不错o( =•ω•= )m清洁能力很强，商品气味挺好的。
# 	洗完以后头发柔顺了很多😏不错的产品。
# 	洗后头皮感觉舒适，朋友推荐的说这款洗发水不错，控油效果特别好，泡沫非常细腻绵密o( =•ω•= )。
# 	味道很香！洗后头皮感觉很舒服，性价比很高值得入手～洗完头发蓬松顺滑😇很好用香味持久，立马洗了感觉不错。
# 	洗完发质柔顺。
# 	包装精美，商品气味很香的味道。
# 	商品气味很香，洗发水好用～控油净化头皮效果不错，而且控油效果持久。
# 	控油效果持久～头发蓬松，商品很好，商品气味香😊包装的很严实。
# 	到的时候包装完整，头发控油又蓬松，控油效果持久。
# 	感觉还不错～性价比很高o(￣▽￣)ｄ香味也持久～效果真的很好。
# 	洗完头发蓬松轻盈。
# 	控油效果真心不错。
# 	洗后头发清爽不油腻！气味很舒服，产品控油效果很好，味道清新。
# 	味道好😆商品气味香。
# 	味道也不错，效果真的很好，性价比极高，头发真的很蓬松。
# 	洗完头发也很蓬松，控油效果特别好。
# 	让人一闻到就感觉很舒适。
# 	价格很合适😗洗出来特别蓬松，商品气味香但不刺鼻，头皮都感觉清爽舒适😝感觉不错～控油挺好。
# 	留香时间长。
# 	洗后头发柔顺有光泽，很清爽的感觉。
# 	头皮很清爽，味道挺好的。
# 	感觉很一般，用一次头发能蓬松个好几天。
# 	洗了效果真心不错，每次洗完头发都感觉清爽自然。
# 	用了之后真的头发第一次这么蓬松，洗完后头皮很清爽～商品气味香但不刺鼻。
# 	去屑效果不错，味道挺好的！就很棒头皮又干净又清爽😚它的清洁力非常强。
# 	头发能持续保持干爽清爽的状态～控油效果真好😝洗完头发也很舒服。
# 	洗完之后蓬松😙洗后头发非常柔顺。
# 	5天后追评用过之后感觉头发都非常蓬松，还能长时间保持头皮的清爽😊商品气味气味好问，这个洗发水泡沫非常丰富。
# 	洗后头发清爽不油腻，洗发水很不错哦！味道挺好的。
# 	头发蓬松。
# 	送的发膜效果很好，洗完头发感觉确实会蓬松点。
# 	控油效果特别的好～宝贝不错。
# 	感觉一般！性价比高多次回购。
# 	一直用效果很好。
# 	15天后追评看看这洗发水就是好。
# 	味道很香。
# 	头发都蓬松了不少，控油很持久。
# 	之前感觉挺好的。
# 	头发比较蓬松～洗感非常舒服😀商品气味好，效果还不错哦！香味很持久。
# 	洗完头发就知道很舒服。
# 	味道清新的让人心情很愉悦。
# 	性价比很高了～味道清新怡人，头发蓬松。
# 	气味很香，而且成分温和φ(≧ω≦*)。
# 	还能长时间保持头发的清爽！这款洗发水真的做到了控油很彻底，洗完头发蓬松！东西保护得很好。
# 	洗完头皮巨干净，而且香味也很清新，洗完又香又顺滑。
# 	头发很柔顺蓬松。
# 	而且洗完真的很蓬松。
# 	第一次买这款洗发水非常好用，感觉很一般。
# 	包装很好，洗完之后头皮很清爽！这款洗发水不仅清洁力强o( =•ω•= )。
# 	味道刚刚好。
# 	泡沫特别的丰富😊洗完之后头发也很滑顺，洗完头发柔顺，东西很好质量很好很喜欢，而且祛油能力很强，用了一次感觉确实不错。
# 	包装很严密～而且头发干爽不油腻，气味也闻得舒服。
# 	洗完很清爽、蓬松φ(≧ω≦*)♪洗发水味道很清新好闻，使用效果很差！洗后头皮感觉很舒服，我觉得他们家控油效果很好。
# 	洗发水控油效果很好。
# 	7天后追评泡沫细腻，洗后头发柔软顺滑。
# 	洗发水非常好用。
# 	而且祛油能力很强😃它的香味也很持久，洗完头发瞬间清爽蓬松。
# 	每次洗头都感觉很控油好几天，泡沫丰富细腻。
# 	洗出来头发很蓬松。
# 	洗发水非常不错很香！控油效果很好。
# 	头发洗的很蓬松。
# 	还是清爽蓬松的感觉太舒服了，控油效果不错。
# 	洗完头发不怎么容易出油了。
# 	洗完之后头发很蓬松。
# 	不错的产品，洗完也不蓬松。
# 	洗完头发蓬松清爽😍不仅控油效果好～味道也很清新，成分温和不刺激。
# 	包装很好。
# 	去屑的效果很不错。
# 	产品使用效果很好，效果还不错哦。
# 	洗发水挺香的，用了脱发严重。
# 	洗完头发很蓬松。
# 	洗完蓬松感让你瞬间爱上它！香味清新，性价比很高，用了之后感觉很清爽，包装很完好。
# 	用过头发也舒服，46天后追评产品真的非常好😆这款洗发水味道清新。
# 	洗完几天不洗头都还挺蓬松的！清洁力度很强，这款洗发水的香味非常持久。
# 	洗发水非常好用～性价比高。
# 	包装也很好。
# 	可以洗了头发很柔顺～洗发水颜值很高哟。
# 	去油效果也明显😉茶洗发水很香，它的泡沫丰富细腻φ(≧ω≦*)♪感觉很不错，护发素很好。
# 	味道特别好～洗发水不错φ(≧ω≦*)♪头发还是很清爽，包装很好很严实。
# 	效果很好，一天不洗就感觉不舒服。
# 	性价比很高，洗完后特别清爽，头发感觉洗的老干净了，商品包装完好～感觉还不错。
# 	用了一两次感觉还不错！味道清新，洗了头发好痒。
# 	立马洗了感觉不错！这洗发水用完后头发太蓬松了，性价比很高。
# 	味道不错。
# 	洗完吹干里面蓬松，每一次都是两瓶两瓶的买用着效果也不错，味道很好～头发柔顺了不少，气味很香很好闻╰(*°▽°*)。
# 	商品气味气味非常好，洗完了蓬松多了。
# 	洗完头发很蓬松，商品气味很香很好闻。
# 	我喜欢这款洗发水的泡沫很丰富和很容易清洗！商品气味还不错。
# 	味道还不错，洗完很清爽，头发的控油效果明显，气味非常好。
# 	用完头发蓬松柔软。
# 	洗后头发很蓬松。
# 	洗完后头发蓬松清香，质量好得没话说～两瓶味道很香很很好闻。
# 	它的泡沫丰富，去油效果好，试了一下感觉还不错，后来多洗几次就发现头发蓬松起来颜值都上去了。
# 	但是现在这款洗发水控油的特别好用。
# 	包装很好，头皮洗得干净，洗发水气味不错。
# 	泡沫细腻，用了效果不错。
# 	感觉还不错，这样头发就更干净舒爽了，性价比很高了，商品很好。
# 	泡沫确实挺细腻😀洗出的头发很蓬松柔顺。
# 	洗完之后香香的还非常的蓬松，泡沫很细腻～而且香味持久，包装完整！控油效果很好。
# 	洗完头发蓬松柔顺不干燥，洗发露的味道清新不刺鼻😁13天后追评包装很精美。
# 	洗完头头发也很蓬松～质量很好，香味持久，头发很柔顺，泡沫非常的细腻😃留香时间很久。
# 	效果很好便宜实惠。
# 	洗了头发蓬松，洗完后很柔顺。
# 	头发很蓬松，包装好，洗起来很舒服，这款洗发水性价比很高～两款味道都不错。
# 	控油效果真的不错😋洗发水很香😁性价比很高，头发在洗完后明显清爽干净了很多！这款洗发水的香味非常持久。
# 	洗后头皮感觉特别清爽😊该商品很好，香味很持久，味道很香。
# 	洗完后的效果很好。
# 	洗完之后头发特别的蓬松。
# 	质量也很好。
# 	这款洗发水不仅清洁力强！泡沫丰富～头发贼清爽蓬松，过后效果很好，香味清新。
# 	清洁力很强。
# 	当天追评是一个好的洗发膏。
# 	我的头发感觉更加柔软φ(≧ω≦*)。
# 	客服态度好。
# 	用一次头发能蓬松个好几天，商品气味很香哦。
# 	用时间长了发现严重脱发o( =•ω•= )m效果还不错。
# 	15天后追评在他家买了好多次了～5天后追评用过之后感觉头发都非常蓬松😃泡沫很丰富。
# 	让我的头发变得清爽柔顺，洗完真的很舒服。
# 	感觉很不错呢第二次买了，洗完头发很蓬松o(￣▽￣)ｄ一开始洗完确实头发不那么容易出油啦。
# 	洗完很舒服😚控油效果非常好o(￣▽￣)ｄ当然洗了头发则很柔弱蓬松～价格很合适。
# 	控油效果也不错。
# 	商品气味味道很香，性价比很高。
# 	洗发水去油效果很好～洗后头发非常清爽。
# 	包装颜值很高，洗完的头发轻盈又蓬松，商品气味很香，还能让头发保持长时间的清爽，控油净化头皮效果不错，东西非常的好。
# 	头发都很干爽蓬松，泡沫丰富。
# 	洗后头发柔软不打结，洗完很蓬松，感觉很不错o( =•ω•= )m商品气味控油的那瓶是很好闻的木质香，香味持久。
# 	包装很好，头发还是保持干爽不油腻。
# 	洗后头发柔软顺滑，控油效果挺好的😊用这个连发膜都不用直接洗完就超级柔顺～包装完好物流快。
# 	洗后头发蓬松柔顺，是比较清新的味道！这款性价比挺高的，留香效果也很好，泡沫细腻且易冲洗。
# 	确实蓬松效果和润滑度都不错，能够有效保持头发的干爽状态，味道也很独特香味持久。
# 	洗完蓬松又没有头皮屑。
# 	用着效果比我预期想象的好。
# 	不会刺激成分也安全，第一次来评价洗发水的效果很好。
# 	洗发露质量也超级好的哦φ(≧ω≦*)♪味道也很清新，使用后头发柔顺亮泽，18天后追评很不错o(￣▽￣)。
# 	商品气味非常香😚洗完头发蓬松又柔顺，控油效果特别好。
# 	控油的现在洗完头发真的很蓬松。
# 	这洗发水用完后头发太蓬松了。
# 	迻款真的强烈推荐已経回焰三次了味道也很香控油效果超，它的泡沫丰富。
# 	气味很香很好闻～洗完头发感觉也很不错，洗完头皮很干净清爽，宝贝很好，现在头发蓬松柔顺。
# 	包装精美别致。
# 	控油效果特别好！头皮也感觉更加舒适。
# 	头发很蓬松，去油效果很好～18天后追评很不错，商品气味很香啊，很清爽的感觉。
# 	洗后头发很顺滑干爽，气味闻着舒服～洗完吹干头顶都蓬松了我是油性皮肤，味道太香了，性价比很高，感觉很不错。
# 	质量挺好。
# 	用着效果还不错～控油效果特别好，第三天头油就已经能让你感觉很明显了，洗完蓬松不油腻可以维持两三天～持久的花香调更是让人心情愉悦。
# 	洗完可蓬松。
# 	洗完蓬松。
# 	每次洗完头发都很柔顺！包装完好物流快！而且香味持久，用了之后确实效果很好，洗后头发清爽顺滑。
# 	洗发水泡沫非常细腻绵密，去屑和控油两组搭配挺好的。
# 	它的控油效果持久，商品气味清淡的香味。
# 	就会发现头发他不蓬松😙味道不错。
# 	去油效果好，洗完之后头发又顺又香还蓬松，我的头发比较干燥洗啦很柔顺的呢，感觉一般╰(*°▽°*)。
# 	性价比很高，蓬松时间很长，相信效果应该也不错。
# 	泡沫很细腻😆洗完头发很柔顺，商品气味很清新淡雅。
# 	味道清新不刺鼻，去屑效果不错，洗发露质量很好，头发蓬松又清爽～商品气味刚打开气味就很香。
# 	感觉还不错，洗发水很温和。
# 	味道很好，感觉不错。
# 	性价比高，气味很浓厚，洗完头很舒服。
# 	期待好的效果，洗完蓬松香香的😙味道是花果香😄真心感觉一般。
# 	10天后追评性价比很高，商品气味挺香的。
# 	东西非常好，而且感觉头发越来越蓬松了！味道不错。
# 	控油效果好，我的头发明显不像以前那么容易出油了，包装精致！味道是淡淡的香。
# 	使用完头发真的很柔顺～8天后追评这个洗发水质地细腻，控油很好o(￣▽￣)。
# 	洗完头发很蓬松可以保持三四天。
# 	效果还不错，洗完头发不仅柔顺还很香，控油效果特别的好～气味清新。
# 	性价比很高。
# 	因为这个洗发水的效果真的很好。
# 	它的泡沫非常丰富，产品挺好的，清洁力度很强。
# 	感觉还不错。
# 	商品气味味道非常好。
# 	很清爽的感觉。
# 	控油效果也不错。
# 	头发吸收很好，洗的时候泡沫特别丰富。
# 	感觉还不错，它的泡沫丰富细腻😍香味比较持久。
# 	控油效果很好。
# 	洗完后很蓬松也很香～价格合适😁气味还不错，而且每次洗完头发清洁的很干净。
# 	控油效果很明显，泡沫丰富，5天后追评刚刚洗完头就感觉头皮特别清爽。
# 	泡沫非常的丰富。
# 	洗后头皮感觉非常清爽。
# 	对于油头真的很友好。
# 	洗完头发很蓬松～味道不错。
# 	性价比很高！3天头发都很蓬松～洗发水味道不错，质量很好。
# 	但是就唯独这次用完头发特别容易油并且发痒有头屑。
# 	而且这款洗发水性价比很高。
# 	而且蓬松时间还很长，香味清新淡雅。
# 	洗后头皮清爽。
# 	味道挺好！控油效果不错。
# 	洗发水很好～泡沫细腻丰富，商品气味清新的花香😆没用护发素头发都很蓬松顺滑。
# 	商品气味挺香的～洗完也很柔顺。
# 	然后洗后头发蓬松，这款控油洗发水确实用起来感觉不错。
# 	商品一如既往的好o(￣▽￣)ｄ蓬松的头发让人心情无比舒畅，洗完之后头皮真的很舒服。
# 	头发特别的香。
# 	洗一次头发就会蓬松一点。
# 	用完头发不再那么容易出油！7天后追评这款洗发水的控油蓬松效果真的不错，洗发水好用，商品气味非常香。
# 	清洁力度很强，味道不错😎而且它的香味也很持久！用了这个洗完蓬松了很多！包装完整😉用后头皮清爽。
# 	感觉还不错！泡沫确实挺细腻。
# 	让我的头发保持清爽，用完感觉很舒服，3天后追评之前发质很差，洗完效果好很不错～性价比很高。
# 	包装完好～洗完的头发很容易梳理～我大油头洗完很清爽！洗完效果还不错。
# 	也觉得效果不错。
# 	洗后头发特别柔顺～味道挺好，洗完头很舒服。
# 	洗发水特别好用，去油效果不错。
# 	这款洗发水性价比很高，包装也很仔细。
# 	效果真的不错，商品气味味道很香，包装很严密。
# 	洗完第二天头发很柔顺，而且洗发水泡沫丰富。
# 	头皮清爽，洗完头发柔顺，去屑效果好。
# 	刚洗完头发很蓬松～宝贝质量不错～质量很好ヽ(✿ﾟ▽ﾟ)ノ香味持久，头发就感觉很清爽。
# 	洗后的头发很清爽，洗完头发柔顺。
# 	洗的头发很柔顺！效果很不错。
# 	觉得东西不错我就会给好评宝贝产品质量很好。
# 	洗完头发很蓬松，控油效果真的不错！控油效果真心好！头发能持续保持干爽清爽的状态。
# 	洗完头发后的清爽感持久，头发非常蓬松柔软。
# 	香味也很持久，洗完很舒服😇10天后追评真的超级好用，它不仅让我的头发保持清爽。
# 	包装完好，气味很好。
# 	控油效果持久，洗完之后头发很蓬松，送的发膜效果很好。
# 	味道也不错😊泡沫丰富。
# 	头发变得格外清爽顺滑，包装很好，味道是淡淡的香，洗发水很细腻，商品气味味道不错，性价比高。
# 	该商品好用。
# 	用完头发也很柔顺～效果很好。
# 	第一次买这款洗发水非常好用，性价比很高！对油头很友好，效果不错～头发柔顺了不少，泡沫丰富细腻。
# 	感觉头发的油分明显减少了，还不错的洗发水。
# 	它的泡沫丰富细腻！包装精美高端大气上档次非常好用很柔顺亮泽很满意，用完的头皮很清爽。
# 	味道也不错😀气味特别好，泡沫也是细腻丰盈，很控油洗完头后特别清爽舒适o(￣▽￣)ｄ10天后追评性价比很高。
# 	泡沫非常的细腻～还能让头发保持长时间的清爽😉包装很好。
# 	洗完以后头发真的蓬松很多😊头发柔顺亮泽！商品气味非常香！感觉效果不错买的，控油效果持久。
# 	商品气味香，控油效果很明显。
# 	感觉挺好的，这个洗发水控油效果很明显。
# 	而且它的泡沫丰富细腻，味道很香，而且洗后头皮感觉非常舒适o(￣▽￣)ｄ之前买的控油效果也还不错。
# 	吹干后头发很柔顺，香味持久，控油挺好😍洗完了头皮很清爽，味道香不刺鼻，感觉性价比还不错。
# 	用了这个洗发水之后还可以隔个一两天好用，用完之后的头发很柔顺～用起来效果还不错！总体性价比很高，商品气味味道挺香的。
# 	洗完后头发蓬松，说自己头发很柔顺，宝贝非常好，控油去屑效果都不错，包装很仔细、严实，味道清新。
# 	产品很好，我买的去油的效果不错。
# 	效果不错，香味很持久，这样头发就更干净舒爽了，洗完头皮贼清爽。
# 	头皮很清爽，洗完的发质蓬松柔软，控油效果也不错，发质真的有变好，性价比高。
# 	洗的时候泡沫丰富。
# 	控油持久香味不刺激，使头发很柔顺～洗完特别舒服，从没想过这么实惠的价格能买到这么好的宝贝！商品气味味道很香。
# 	它让我的头发保持清爽😚香味持久。
# 	控油效果很不错，洗感超级舒服～而且这个洗发水的性价比很高！泡沫细腻丰富，感觉控油也一般吧！发现在洗发后头皮感觉清爽。
# 	用着效果还不错。
# 	用一次头发能蓬松个好几天。
# 	洗完头发就知道很舒服。
# 	还不错的洗发水～包装完好，控油效果特别好。
# 	头发蓬松立体！洗完很清爽～商品气味味道很香。
# 	产品很好。
# 	质量很好。
# 	用了之后真的头发第一次这么蓬松。
# 	控油效果也不错，气味闻着舒服，而且控油能力强，洗完头发蓬松柔顺不干燥。
# 	洗完头发蓬松顺滑！头皮瞬间都感觉清爽了不少，这款产品非常好。
# 	它的泡沫丰富细腻。
# 	用着效果比我预期想象的好，整体感觉性价比很高╰(*°▽°*)╯用时间长了发现严重脱发。
# 	光滑头发还香，泡沫丰富。
# 	味道很香～用的头皮舒服，洗发水很温和很不错。
# 	一直都是用这个牌子的洗发水好用。
# 	7天后追评自己用的好，包装完好。
# 	味道也特别好！包装完好。
# 	气味特别好。
# 	洗完头发就知道很舒服！控油能力也超级好。
# 	洗了之后头发特清爽，洗完头发柔顺，产品很好，让人感觉特别舒适，控油效果也不错。
# 	而且它成分温和！味道很好！香味也很清新，洗完头发感觉很清爽也很蓬松，相信这是一款不错的产品。
# 	洗完后很蓬松也很香。
# 	洗完头发很蓬松，吹干后头发柔顺了不少，包装也很仔细。
# 	这个洗发水洗完之后实在是太香了！头发洗的很干净～味道很好闻而且留香久。
# 	发现控油效果比一般的要好。
# 	清洁力度很强～香味比较持久。
# 	泡沫丰富区细腻，头发蓬松的发量都翻倍了！洗发水味道很清新好闻。
# 	这款洗发水可以保持好几天蓬松。
# 	不然老是感觉自己头发洗不干净一样，效果还不错。
# 	感觉一般，商品气味好香～头发柔顺。
# 	洗完头发很顺味道也很香，发质真的有变好，头发清爽多了，5天后追评洗发水很不错。
# 	商品气味不错，性价比高～它的香味也很持久！头发很蓬松。
# 	质量很好～效果不错，泡沫细腻，洗完了以后头发非常的蓬松。
# 	感觉还不错。
# 	泡沫很丰富，洗后头发柔顺不打结。
# 	它不仅让我的头发保持清爽，泡沫丰富😇洗发水不错，而且它的成分温和，包装非常仔细、严实。
# 	控油效果不错！洗后头皮清爽！香味清新不刺鼻ヽ(✿ﾟ▽ﾟ)ノ洗完后头发很顺滑蓬松。
# 	用后头发也能蓬松好久，泡沫丰富，气味挺香😃而且洗完很舒服～经济实惠性价比很高。
# 	洗发水颜值很高哟😍洗后头发柔顺蓬松，发质真的有变好，没有评价里写的味道那么香～效果不错。
# 	泡沫丰富，洗完头发蓬松柔顺，吹干头发后很容易梳理，味道很香。
# 	洗完后很蓬松也很香，7天后追评泡沫细腻φ(≧ω≦*)♪发质看起来超级好，控油效果持久，我的头发变得既干净又柔顺。
# 	效果真的不错，商品气味很好。
# 	效果也很好～头皮一整天都能保持清爽。
# 	而且头发比较容易爱出油。
# 	洗完头发感觉头皮很舒服，留香时间长～从没想过这么实惠的价格能买到这么好的宝贝。
# 	性价比高！因为这个洗发水的效果真的很好。
# 	用了头发蓬松顺滑，挺好的一款洗发水，商品气味非常香😏洗护效果明显，性价比高。
# 	头发清爽多了，这个控油效果挺好，整体感觉控油力度还是不错的不至于洗完黏腻。
# 	但是头发特别容易出油，控油能力很强😁洗完头很蓬松。
# 	而且洗后头皮感觉非常清爽，洗完头发之后非常蓬松，味道不错，商品气味特别香！包装完整。
# 	嗯洗发水清洁力和控油都很不错，商品很好。
# 	洗后头发柔顺不打结。
# 	洗起来头发很蓬松。
# 	kono卡厘洗发水到货啦质量不错😀商品气味气味很舒服😍它的泡沫丰富。
# 	洗了头发也蓬松。
# 	这个洗发水用过后很清爽的感觉，头发柔顺了不少。
# 	颜值也高效果也好，洗完之后头发非常的蓬松，头皮很舒爽😏头发的控油效果明显，感觉很一般。
# 	头发柔顺了许多，包装很好，洗完头发特别清爽。
# 	这款洗发水的控油效果真的很好！性价比很高了，洗后头发柔软顺滑，商品包装严实😝泡沫丰富。
# 	泡沫非常的细腻。
# 	洗完头发瞬间清爽蓬松～香味持久轻盈，性价比很高。
# 	头发柔顺亮泽！洗完头发蓬松清爽，而且香味持久。
# 	让我的头发一整天都保持清爽，洗完吹干头顶都蓬松了我是油性皮肤，味道很好😇控油去屑效果都不错。
# 	味道也很不错，头发很蓬松。
# 	洗发水非常好用。
# 	洗完清爽蓬松😆清洁效果也是很不错的，气味清新！吹干味道还很香。
# 	去油效果也明显，用这个连发膜都不用直接洗完就超级柔顺，性价比很高，而且洗后头皮感觉非常清爽，留香时间很久～控油效果好。
# 	闻着味道挺香的，洗完头发特别清爽。
# 	而且洗完头发很蓬松，泡沫细腻丰富😂控油效果非常好φ(≧ω≦*)。
# 	味道是花果香～香味好！立马洗了感觉不错，控油能力很强。
# 	效果不错，洗完之后头发很蓬松。
# 	姐妹们泡沫丰富细腻，去油效果好，味道不错，吹干后头发柔顺了不少，10天后追评性价比很高。
# 	去油效果也很好！洗完头发很清爽～颜值高！头发也蓬松。
# 	包装很严实，客服态度特别好，我感觉很不错，味道也挺香。
# 	味道非常香，包装很好。
# 	物流很快客服态度很好物超所值多次购买o(￣▽￣)ｄ味道很好闻而且留香久。
# 	洗发水不错。
# 	这款洗发水去油力还是很不错的，控油效果很好！使用后头发柔顺亮泽ヽ(✿ﾟ▽ﾟ)ノ商品气味洗完头发很香😝蓬松时间很长。
# 	洗完头发很蓬松，感觉头发越来越好！性价比很高，泡沫丰富，包装完好。
# 	洗护效果非常好。
# 	味道好！感觉洗完头都变清爽了。
# 	头皮都感觉清爽舒适，产品非常好～很不错的洗发水，3天后追评之前发质很差，性价比很高。
# 	洗完头发蓬松，用了一瓶打开味道很香。
# 	商品气味味道很香，洗完很蓬松，留香时间久，头发发质已经差的不行了😊性价比高哦～头皮超级清爽。
# 	洗完头蓬松了，商品气味清新的花香，效果很好，洗后头发清爽。
# 	最主要的是成分很安全～洗完头发蓬松又柔顺。
# 	这个洗发水洗完之后实在是太香了！香味清新宜人，头发真的很蓬松。
# 	洗发水非常好用。
# 	使用效果还不错，冲洗后头发干净清爽。
# 	效果很好，洗的时候感觉很清爽。
# 	气味也很香。
# 	头发蓬松有光泽。
# 	用完头发蓬松柔软～洗完很柔顺。
# 	商品气味味道很香～我觉得洗了头发特别蓬松，整体控油效果很不错o( =•ω•= )。
# 	洗完头发感觉很清爽也很蓬松，物流快包装好。
# 	洗发水非常好用！用起来头发很蓬松。
# 	头发也非常柔软洗的～商品气味非常香😂洗完头发漂顺蓬松，这个kono的控油洗发水和水润亮泽护发素都是正品质量很好。
# 	效果不明显，洗完头发后很柔顺！商品气味洗完头发很香，清洁力很强，头皮很清爽！控油效果很好。
# 	洗完很蓬松！我的头发变得更加清爽。
# 	效果还是不错的φ(≧ω≦*)♪我的头发变得更加清爽，控油效果真好。
# 	感觉头发的油分明显减少了～头发立马蓬松了。
# 	气味还不错，对头发是油头控油效果好，包装也完好，味道是花果香。
# 	感觉还不错诶就搜了同款。
# 	吹干后头发很柔顺😆性价比很高，控油效果和去屑效果味道什么的都不错。
# 	洗完也挺柔顺的！洗后头皮感觉特别清爽，性价比很高。
# 	12天后追评控油效果很不错，控油效果特别好洗完头发很清爽蓬松。
# 	商品气味很香很好闻，15天后追评我的头发一直以来都容易头油头痒！包装很好。
# 	洗完挺蓬松的。
# 	控油效果很好😃包装非常仔细、严实～洗完很蓬松，去屑能力很强，洗了头发柔顺。
# 	产品质量一如既往的好😘洗发水很温和很不错，而且头发的质感也变得更加柔顺。
# 	性价比高。
# 	气味很好。
# 	味道挺好，洗后头发轻盈柔顺。
# 	洗完头发特别清爽，头发蓬松的状态可以撑好几天，不错的产品，商品气味特别香。
# 	洗完头很蓬松，头皮感觉非常清爽，泡沫丰富，洗护效果明显，味道特别好。
# 	泡沫丰富，洗后头皮清爽～性价比很高😆控油效果好到离谱。
# 	洗起来头发很蓬松，控油效果也很好，包装完整。
# 	洗发水用起来挺温和的，14天后追评洗发水很好揉搓清洗！这款洗发水不仅清洁力强。
# 	洗完很蓬松😙去油效果很好。
# 	蓬松效果特别好！头发也变得柔顺了许多，商品气味洗发水味道很很香。
# 	包装严实～使用后香味持久😁头发真的很蓬松。
# 	这款洗发水味道好香哦。
# 	清新的味道，效果也很差洗过后发粗糙干皮价格一点也不优惠啊。
# 	洗完的头发很容易梳理。
# 	而且维持的时间也比较长😇这么好的东西还这么实惠。
# 	控油效果持久o( =•ω•= )m气味很香。
# 	洗发水很不错。
# 	东西不错，味道很香。
# 	不仅控油效果好！头发容易油，价格很合适，香味清新不刺鼻！使用过程感觉头皮特别清爽。
# 	性价比很高～感觉用了还不错，洗完头发清爽蓬松。
# 	头发很柔顺，效果很不错😝很控油洗完头发很清爽，味道很香。
# 	感觉不错，洗完头发很清爽。
# 	洗了头发柔顺ヽ(✿ﾟ▽ﾟ)。
# 	头发不仅干净，控油效果很好😉洗完清爽不油腻，去屑效果不错。
# 	洗完头皮贼清爽，头发控油蓬松，效果不错，控油效果嘎嘎好！商品气味香ヽ(✿ﾟ▽ﾟ)ノ泡沫丰富区细腻。
# 	客服服务态度好，能够有效保持头发的干爽状态😆商品气味清新的香味扑鼻而来。
# 	味道清新，质量也很好。
# 	让人心情愉悦，蓬松效果也不错。
# 	使用后确实控油效果很好。
# 	性价比高，香味也不持久～洗完很清爽，商品气味气味非常好。
# 	一直都是用这个牌子的洗发水好用，快递包装完好，味道很香，洗后头发清爽不油腻，它的泡沫丰富细腻。
# 	泡沫丰富细腻，控油效果很不错，洗的时候感觉很清爽，控油效果非常好，味道很香。
# 	洗完很蓬松。
# 	味道清新。
# 	头发洗完很清爽，去油效果很好，洗发水的的花香调香味清新好闻。
# 	控油效果非常好。
# 	洗完头发蓬松又柔顺。
# 	头发也很蓬松😁官旗性价比很高，这款控油洗发水味道很清新很淡雅。
# 	味道不错。
# 	很香很好闻洗完之后头发也炒鸡的蓬松。
# 	气味很好，它的清洁力很强！洗后头发柔软不打结，洗完很柔顺😃味道是淡淡的香。
# 	洗发水非常好用，感觉还不错，这款洗发水真的做到了控油很彻底。
# 	洗完之后头发特别的蓬松～还能长时间保持头发的清爽。
# 	洗完头发很蓬松！感觉很不错！气味很清新，泡沫也很丰富绵密。
# 	洗发水很高级用着很不错的哦😋味道挺香的～我的头发比较干燥洗啦很柔顺的呢，现在这个洗发水的控油效果真的很持久o( =•ω•= )m质量非常好。
# 	味道不错！洗发水温和洁净，头发比较清爽蓬松。
# 	说自己头发很柔顺，味道也很香，洗发水味道特别好，去头油的效果很明显，商品气味不错。
# 	控油效果很好。

# %% [markdown]
# pair_useful保存为csv(便于展示)

# %%
print(pair_useful)
import csv  

# 将值列表转换为字符串  
pair_useful_str = {key: ' '.join(values) for key, values in pair_useful.items()}  

# 写入 CSV 文件  
with open('../data(temp)/pair_useful.csv', mode='w', newline='', encoding='utf-8') as csvfile: 
    writer = csv.writer(csvfile)  
    writer.writerow(['Key', 'Value'])  # 写入列名  

    # 遍历字典并写入每个键及其对应的值字符串  
    for key, value_str in pair_useful_str.items():  
        writer.writerow([key, value_str])  # 写入键和合并后的字符串值
# Out:
# {'效果': ['好', '不错', '明显', '差'], '头发': ['蓬松', '柔顺', '清爽', '香', '容易', '舒服', '柔软', '干净', '滑顺', '干爽', '好', '枯燥', '轻'], '味道': ['香', '好', '清新', '不错', '清淡', '甜腻'], '气味': ['香', '好', '不错', '清新', '舒服', '清爽', '细腻', '清淡', '浓厚'], '性价比': ['高'], '包装': ['好', '仔细', '严实', '精致', '完整', '完好', '精美', '严密', '一般', '干净'], '质量': ['好'], '洗完': ['蓬松', '清爽', '柔顺', '舒服', '香', '干痒'], '洗发水': ['好', '香', '不错', '温和', '细腻', '清爽'], '头皮': ['清爽', '舒服', '干净', '舒适', '舒爽'], '产品': ['好', '不错'], '感觉': ['不错', '清爽', '舒服', '好', '一般', '舒适', '蓬松', '明显', '香'], '泡沫': ['丰富', '细腻'], '服务态度': ['好'], '东西': ['好', '不错'], '能力': ['强', '不错', '好'], '商品': ['好', '不错'], '清洁力': ['强'], '控油': ['好', '持久', '清爽', '彻底'], '香味': ['持久', '清新', '好'], '力度': ['强'], '颜值': ['高'], '态度': ['好', '积极'], '宝贝': ['好', '不错'], '产品质量': ['好'], '质地': ['好'], '上头': ['温和'], '追评': ['不错', '好'], '油头': ['友好', '好'], '体验感': ['好', '差'], '发质': ['好', '差'], '客服': ['好'], '成分': ['温和', '安全', '好'], '好闻': ['香'], '产品包装': ['好'], '变得': ['蓬松', '柔顺'], '吸收': ['好'], '商品质量': ['好'], '好用': ['不错', '香', '柔顺'], '洗头': ['清爽'], '洗头水': ['好'], '洗起来': ['舒服'], '护发素': ['好'], '洗感': ['舒服'], '价格': ['合适'], '体验': ['不错', '好'], '感受': ['不错'], '洗出来': ['蓬松', '干净'], '口碑': ['不错'], '时间': ['长', '久'], '洗发': ['柔顺'], '脱发': ['严重'], '油腻': ['清爽'], '头顶': ['干净', '清爽'], '发现': ['好'], '留香': ['久', '好'], '品质': ['好'], '喜欢': ['香'], '顺滑': ['蓬松'], '大油头': ['友好'], '出油': ['严重'], '头油': ['慢'], '心情': ['愉悦'], '按摩': ['舒服'], '赠品': ['香'], '不算': ['贵', '低'], '光泽度': ['高'], '减少': ['明显'], '出厂日期': ['新'], '功效': ['好'], '印象': ['好'], '去屑': ['干净'], '发货': ['迅速'], '品牌': ['不错'], '头皮屑': ['严重'], '好看': ['好'], '揉搓': ['温和'], '提好': ['好'], '有用': ['香'], '材质': ['好'], '洗发露': ['香']}

# %% [markdown]
# ns_dict保存为csv(便于展示，可以不运行)

# %%
import csv  
print(ns_dict)
# 定义要保存的 CSV 文件名  
csv_file_name = '../data(temp)/ns_dict.csv'  

# 打开 CSV 文件进行写入  
with open(csv_file_name, mode='w', newline='', encoding='utf-8') as csv_file:  
    writer = csv.writer(csv_file)  
    
    # 写入标题行  
    writer.writerow(['对象', 'pattern', '观点词', '个数'])  
    
    # 遍历每个对象、观点词和对应的 pattern 和个数  
    for obj, opinions in ns_dict.items():  
        for opinion, patterns in opinions.items():  
            for pattern, count in patterns.items():  
                # 写入四列数据  
                writer.writerow([obj, pattern, opinion, count])  
data = []  

# 从CSV中读取数据  
with open(csv_file_name, mode='r', encoding='utf-8') as csv_file:  
    reader = csv.reader(csv_file)  
    
    # 读取标题行  
    header = next(reader)  
    
    # 读取其他行  
    for row in reader:  
        data.append(row)  

# 随机打乱数据行 
random.seed(10) 
random.shuffle(data)  

# 将打乱后的数据写入新的CSV文件  
with open(csv_file_name, mode='w', newline='', encoding='utf-8') as csv_file:  
    writer = csv.writer(csv_file)  

    # 写入标题行  
    writer.writerow(header)  
    
    # 写入打乱后的数据  
    writer.writerows(data)  


print(f"数据已保存到 {csv_file_name}")
# Out:
# {'头发': {'蓬松': {'立马-': 1.0, '又 巨显 发量 的+': 1.0, '能-': 1.0, '变得-': 1.0, '的+': 3.0, '很-': 61.0, '真的 很 柔顺 很-': 1.0, '都 很-': 5.0, '比较-': 2.0, '感觉 很-': 1.0, '也 很-': 7.0, '真的 挺-': 1.0, '比 以前-': 1.0, '蓬蓬 的+': 1.0, '依旧-': 1.0, '更-': 1.0, '轻盈 又-': 2.0, '贼 清爽-': 1.0, '柔顺-': 3.0, '特别 的-': 2.0, '都-': 2.0, '洗完 真的 很-': 1.0, '真的 很-': 6.0, '之后 很 立体-': 1.0, '越来越-': 3.0, '还-': 1.0, '也 超级-': 1.0, '还是-': 1.0, '清爽-': 3.0, '超级-': 2.0, '瞬间 清爽-': 1.0, '干净 又-': 1.0, '就 会-': 1.0, '轻盈-': 1.0, '巨-': 2.0, '好 几天 都 是-': 1.0, '还是 很 清爽-': 1.0, '洗完 第一天 一点 也 不-': 1.0, '既-': 1.0, '很 顺滑-': 2.0, '很 清爽-': 1.0, '也 炒 鸡 的-': 1.0, '非常 的-': 4.0, '有 多 去 油腻 、 有 多-': 1.0, '就 头发 都 巨-': 1.0, '都 巨-': 1.0, '特别-': 3.0, '也-': 2.0, '就 很-': 1.0, '变得 很-': 1.0, '顺滑-': 1.0, '非常-': 4.0, '都 能-': 1.0, '一 开始 是 有 一点点-': 1.0, '使用 起来 这个-': 1.0, '的 洗完+': 1.0, '特别 顺滑-': 1.0, '后 很-': 1.0, '确实 很-': 2.0, '一 整个-': 1.0, '就 没有 支棱 起来 过来 现在 头发 都 是-': 1.0, '都 是-': 1.0, '后 挺-': 1.0, '之后 非常-': 1.0, '自然-': 1.0, '感觉 很 清爽 也 很-': 1.0, '感觉 至少-': 1.0, '洗 后 很-': 1.0, '也 挺-': 1.0, '也 是 很-': 1.0, '后 真的 很-': 1.0, '还 挺-': 1.0, '太-': 1.0, '最近 很-': 1.0, '一-': 1.0, '还是 巨-': 1.0, '现在 吹干 后 真的 很-': 1.0, '可以-': 1.0, '洗 的 很-': 2.0, '控油-': 1.0, '又 顺 又 香 还-': 1.0, '则 很 柔弱-': 1.0, '很润 很-': 1.0, '都 很 干爽-': 1.0, '洗完 很-': 1.0, '挺-': 1.0, '也 更加-': 1.0, '柔软+': 1.0, '明显 变得-': 1.0, '很 顺滑 很-': 1.0, '比 之前-': 1.0, '也 能-': 1.0, '确实-': 1.0, '感觉 好-': 1.0, '感觉 确实 会-': 1.0, '洗完-': 1.0, '第三天 都 是-': 1.0, '看起来 更加-': 1.0, '很 柔顺-': 1.0, '他 不-': 1.0, '之后 五天 都 很-': 1.0, '是-': 1.0, '都 掉 了 还 怎么-': 1.0, '没有 描述 的-': 1.0}, '巨显': {'发量 的+': 1.0}, '好': {'能 蓬松 个-': 1.0, '光泽度 非常 的-': 1.0, '真的-': 1.0, '的 洗发水 真的 是+': 1.0, '都 被 呵护 得 很-': 1.0, '吸收 很-': 2.0, '洗完+': 1.0, '细软 的 人 用 着-': 1.0, '泡沫 绵密 我 大 油头 洗完 之后+': 1.0, '能 管好 就-': 1.0, '是 油头 控油 效果-': 1.0, '控油 效果 很-': 1.0, '很-': 1.0, '几次 了 洗完 之后+': 1.0, '用 洗完+': 1.0, '感觉 很-': 1.0, '而且 搭配 使用 水润 亮泽 护发素 可以 使+': 1.0, '以前 发质 很-': 1.0, '的 香味 也 很-': 1.0, '感觉-': 1.0, '干 了 看起来-': 1.0, '掉 得-': 1.0}, '不涩': {'一点 都-': 1.0}, '温和': {'上 揉搓 很-': 1.0, '都 非常 的-': 1.0, '洗完+': 1.0}, '柔顺': {'非常-': 5.0, '真的 很-': 3.0, '很-': 28.0, '变得 既 干净 又-': 1.0, '变得-': 5.0, '真的 就 很-': 1.0, '真的 又-': 1.0, '特别-': 3.0, '非常 的-': 1.0, '清爽 又-': 1.0, '香 飘飘 的-': 1.0, '就 很-': 1.0, '变得 更加-': 2.0, '特别 特别-': 1.0, '也 很-': 8.0, '就 头发 都 巨 蓬松-': 1.0, '都 巨 蓬松-': 1.0, '蓬松-': 4.0, '也 比较-': 1.0, '比较-': 1.0, '蓬松 又-': 1.0, '很 蓬松-': 4.0, '也 变-': 1.0, '清爽-': 1.0, '洗 过后 很-': 1.0, '也 挺-': 1.0, '也 变得 可-': 1.0, '超级-': 1.0, '变得 清爽-': 1.0, '发丝 也-': 1.0, '也 太-': 1.0, '之后 也 很-': 1.0, '都 很-': 1.0, '也 十分-': 1.0, '的 质感 也 变得 更加-': 2.0, '比较 干燥 洗 啦 很-': 1.0, '洗 了 很-': 1.0, '也 变得-': 2.0, '不仅-': 1.0, '重现-': 1.0, '也 很 非常 的-': 1.0, '很丝 滑-': 1.0, '依然 保持-': 1.0}, '直接': {'也 是 可以-': 1.0}, '干燥': {'容易-': 1.0, '不会 变得-': 1.0, '也 不-': 2.0, '比较-': 1.0, '不-': 7.0, '会-': 1.0, '不会-': 2.0, '变得-': 2.0, '蓬松 柔顺 不-': 1.0, '过度-': 1.0}, '明显': {'在 洗完 后-': 1.0, '的 感觉 到+': 1.0, '感觉 第二天+': 1.0, '质 都 有 了-': 1.0, '的 油分-': 1.0, '的 油腻感-': 2.0, '出 油 情况-': 1.0, '的 控油 效果-': 1.0, '出 油-': 1.0}, '清爽': {'在 洗完 后 明显-': 1.0, '蓬松 又-': 1.0, '干净-': 2.0, '特别-': 1.0, '超级-': 1.0, '后 喜欢 这种 干爽 和-': 1.0, '很-': 15.0, '挺-': 1.0, '贼-': 1.0, '瞬间-': 1.0, '后 的-': 1.0, '还是 很-': 3.0, '洗完 之后 特别 干净-': 1.0, '保持-': 7.0, '蓬松-': 3.0, '都-': 1.0, '后 感觉-': 1.0, '柔顺 自然-': 1.0, '不-': 1.0, '变得 很 蓬松-': 1.0, '后-': 1.0, '都 感觉-': 1.0, '也 很-': 1.0, '很 顺滑-': 1.0, '感觉 很-': 1.0, '就 感觉 很-': 2.0, '变得-': 4.0, '更 持久-': 1.0, '依然-': 1.0, '非常-': 1.0, '明显 变得-': 2.0, '一整天 都 保持-': 2.0, '变得 更加-': 4.0, '保持 一整天 的-': 1.0, '保持 了 一整天 的-': 1.0, '保持 长时间 的-': 2.0, '蓬松 很-': 1.0, '依然 保持-': 1.0, '可以 保持-': 1.0, '特-': 1.0, '洗完 很-': 1.0, '变得 格外-': 1.0, '依然 保持 柔顺 和-': 1.0, '看起来 更加-': 1.0, '能 持续保持 干爽-': 1.0, '是 蓬松-': 1.0}, '干净': {'在 洗完 后 明显 清爽-': 1.0, '很-': 2.0, '变得 既-': 1.0, '洗完 之后 特别-': 1.0, '感觉 洗 的 老-': 1.0, '就 更-': 3.0, '清爽-': 2.0, '洗 不-': 1.0, '特别-': 2.0, '和 头皮 都 很-': 1.0, '非常-': 2.0, '不仅-': 3.0, '洗 的 很-': 1.0, '上 的 油污 也 洗 的 很-': 1.0, '清洁 的 很-': 1.0}, '干爽': {'特别-': 1.0, '后 喜欢 这种-': 1.0, '是 那种 超-': 1.0, '还是 保持-': 1.0, '都 很-': 1.0, '很 顺滑-': 1.0, '很-': 1.0, '能 持续保持-': 1.0, '保持-': 1.0}, '舒服': {' ...
# 数据已保存到 ../data(temp)/ns_dict.csv

# %% [markdown]
# pair_score保存为csv(便于展示)

# %%
print('pair_score',pair_score[:20])
with open('../data(temp)/pair_score.csv', mode='w', newline='', encoding='utf-8') as csvfile:  
    writer = csv.writer(csvfile)  
    writer.writerow(['Pair', 'Score'])  # 写入列名  
    writer.writerows(pair_score)  # 写入数据
# Out:
# pair_score [('效果\t好', 190.32950411147868), ('头发\t蓬松', 126.3945117883121), ('味道\t香', 70.7282132914151), ('气味\t香', 62.416323882483624), ('头发\t柔顺', 60.14794005867908), ('性价比\t高', 57.41753087280957), ('包装\t好', 56.420237481209476), ('质量\t好', 42.71421457597844), ('洗完\t蓬松', 35.73685531973345), ('洗发水\t好', 32.111506470088514), ('头发\t清爽', 30.865528643735292), ('洗发水\t香', 29.868033807404387), ('味道\t好', 25.85738378159592), ('洗发水\t不错', 25.655257906629966), ('效果\t不错', 25.132216990883926), ('头皮\t清爽', 25.09434917103873), ('产品\t好', 23.072515202170752), ('洗完\t清爽', 22.99379760032052), ('感觉\t不错', 22.246410141486567), ('洗完\t柔顺', 21.280419614157775)]
